# %%
# %%capture
# %cd ..

# %%
import matplotlib.pyplot as plt
import numpy as np
import torch
from src.dataset import create_sifim_datasets
from src.plot.timeseries_analysis import create_subplots

# %%
tr_dataset, vl_dataset, ts_dataset = create_sifim_datasets(vl_perc=0.2, ts_perc=0.2, noise=0.005)

origin_models = {m_name: torch.load(f'models/{m_name}.torch') for m_name in ['ESN', 'LSTM']}

# %%
create_subplots(
    ts_dataset,
    feature=[('energia_apparente_importata_sistema', 'System imported apparent energy effective', 'kWh')],
    models=origin_models,
    plotpath=f'plots/',
    n_example=5,
    zoom_left=40,
    zoom_right=10,
)

# %%
create_subplots(
    ts_dataset,
    feature=[('energia_attiva_importata_di_sistema', 'System imported active energy effective', 'kWh')],
    models=origin_models,
    plotpath=f'plots/',
    n_example=12,
    zoom_left=45,
    zoom_right=15,
)

# %%
create_subplots(
    ts_dataset,
    feature=[('potenza_attiva_di_sistema', 'Active system power', 'kWh')],
    models=origin_models,
    plotpath=f'plots/',
    n_example=20,
    zoom_left=50,
    zoom_right=5,
)

# %%
create_subplots(
    ts_dataset,
    feature=[('frequenza', 'Frequency', 'Hz')],
    models=origin_models,
    plotpath=f'plots/',
    n_example=2,
    zoom_left=40,
    zoom_right=8,
)

# %%
create_subplots(
    ts_dataset,
    feature=[('tensione_di_sistema', 'System voltage', 'Volt')],
    models=origin_models,
    plotpath=f'plots/',
    n_example=3,
    zoom_left=50,
    zoom_right=15,
)

# %%
create_subplots(
    ts_dataset,
    feature=[('corrente_di_sistema', 'System current', 'Ampere')],
    models=origin_models,
    plotpath=f'plots/',
    n_example=3,
    zoom_left=40,
    zoom_right=6,
)

# %%
create_subplots(
    ts_dataset,
    feature=[('o10o_componente_corrente_fase_1', 'Third harmonic current', '%')],
    models=origin_models,
    plotpath=f'plots/',
    n_example=10,
    zoom_left=50,
    zoom_right=18,
)

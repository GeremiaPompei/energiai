# %%
# %%capture
# %cd ..

# %%
import matplotlib.pyplot as plt
import numpy as np
import torch
from src.dataset import create_sifim_datasets
from src.plot.timeseries_analysis import create_subplots

# %%
tr_dataset, vl_dataset, ts_dataset = create_sifim_datasets(vl_perc=0.2, ts_perc=0.2)

origin_models = {label: torch.load(f'models/{m_name}.torch') for label, m_name in [('DeepESN', 'ESN'), ('LSTM', 'LSTM')]}

# %%
"""create_subplots(
    ts_dataset,
    feature=[('energia_apparente_importata_sistema', 'System imported apparent energy effective', 'kWh')],
    models=origin_models,
    plotpath=f'plots/',
    n_example=5,
    zoom_left=40,
    zoom_right=4,
    ymax=2,
)"""
# Out:
# "create_subplots(\n    ts_dataset,\n    feature=[('energia_apparente_importata_sistema', 'System imported apparent energy effective', 'kWh')],\n    models=origin_models,\n    plotpath=f'plots/',\n    n_example=5,\n    zoom_left=40,\n    zoom_right=4,\n    ymax=2,\n)"

# %%
"""create_subplots(
    ts_dataset,
    feature=[('energia_attiva_importata_di_sistema', 'System imported active energy effective', 'kWh')],
    models=origin_models,
    plotpath=f'plots/',
    n_example=5,
    zoom_left=45,
    zoom_right=15,
    ymax=2,
)"""
# Out:
# "create_subplots(\n    ts_dataset,\n    feature=[('energia_attiva_importata_di_sistema', 'System imported active energy effective', 'kWh')],\n    models=origin_models,\n    plotpath=f'plots/',\n    n_example=5,\n    zoom_left=45,\n    zoom_right=15,\n    ymax=2,\n)"

# %%
"""create_subplots(
    ts_dataset,
    feature=[('potenza_attiva_di_sistema', 'Active system power', 'kWh')],
    models=origin_models,
    plotpath=f'plots/',
    n_example=6,
    zoom_left=50,
    zoom_right=5,
    ymax=2,
)"""
# Out:
# "create_subplots(\n    ts_dataset,\n    feature=[('potenza_attiva_di_sistema', 'Active system power', 'kWh')],\n    models=origin_models,\n    plotpath=f'plots/',\n    n_example=6,\n    zoom_left=50,\n    zoom_right=5,\n    ymax=2,\n)"

# %%
"""create_subplots(
    ts_dataset,
    feature=[('frequenza', 'Frequency', 'Hz')],
    models=origin_models,
    plotpath=f'plots/',
    n_example=10,
    zoom_left=40,
    zoom_right=4,
    ymax=2,
)"""
# Out:
# "create_subplots(\n    ts_dataset,\n    feature=[('frequenza', 'Frequency', 'Hz')],\n    models=origin_models,\n    plotpath=f'plots/',\n    n_example=10,\n    zoom_left=40,\n    zoom_right=4,\n    ymax=2,\n)"

# %%
create_subplots(
    ts_dataset,
    feature=[('tensione_di_sistema', 'System voltage', 'Volt')],
    models=origin_models,
    plotpath=f'plots/',
    n_example=12,
    zoom_left=45,
    zoom_right=15,
    ymax=2,
    legend_loc_2='lower left'
)

# %%
create_subplots(
    ts_dataset,
    feature=[('corrente_di_sistema', 'System current', 'Ampere')],
    models=origin_models,
    plotpath=f'plots/',
    n_example=1,
    zoom_left=60,
    zoom_right=10,
    ymax=2,
    legend_loc_2='upper center'
)

# %%
"""create_subplots(
    ts_dataset,
    feature=[('o10o_componente_corrente_fase_1', 'Third harmonic current', '%')],
    models=origin_models,
    plotpath=f'plots/',
    n_example=10,
    zoom_left=50,
    zoom_right=18,
    ymax=2,
)"""
# Out:
# "create_subplots(\n    ts_dataset,\n    feature=[('o10o_componente_corrente_fase_1', 'Third harmonic current', '%')],\n    models=origin_models,\n    plotpath=f'plots/',\n    n_example=10,\n    zoom_left=50,\n    zoom_right=18,\n    ymax=2,\n)"

# %%
# %%capture
# %cd ..

# %%
import matplotlib.pyplot as plt
import numpy as np
import torch
from src.dataset import SifimDataset
from src.plot.timeseries_analysis import create_subplots

# %%
ts_dataset = SifimDataset(start=0.8, end=1.0, test=True, noise=0.003)

origin_models = {m_name: torch.load(f'models/{m_name}.torch') for m_name in ['ESN', 'LSTM']}  #'ESN_BPTT'

# %%
create_subplots(
    ts_dataset,
    feature=[('energia_apparente_importata_sistema', 'System imported apparent energy effective', 'kWh')],
    models=origin_models,
    plotpath=f'plots/',
    n_example=5,
    zoom_left=40,
    zoom_right=10,
)

# %%
create_subplots(
    ts_dataset,
    feature=[('energia_attiva_importata_di_sistema', 'System imported active energy effective', 'kWh')],
    models=origin_models,
    plotpath=f'plots/',
    n_example=12,
    zoom_left=45,
    zoom_right=15,
)

# %%
create_subplots(
    ts_dataset,
    feature=[('potenza_attiva_di_sistema', 'Active system power', 'kWh')],
    models=origin_models,
    plotpath=f'plots/',
    n_example=20,
    zoom_left=50,
    zoom_right=5,
)

# %%
create_subplots(
    ts_dataset,
    feature=[('frequenza', 'Frequency', 'Hz')],
    models=origin_models,
    plotpath=f'plots/',
    n_example=2,
    zoom_left=40,
    zoom_right=15,
)

# %%
create_subplots(
    ts_dataset,
    feature=[('tensione_di_sistema', 'System voltage', 'Volt')],
    models=origin_models,
    plotpath=f'plots/',
    n_example=10,
    zoom_left=50,
    zoom_right=18,
)

# %%
create_subplots(
    ts_dataset,
    feature=[('corrente_di_sistema', 'System current', 'Ampere')],
    models=origin_models,
    plotpath=f'plots/',
    n_example=14,
    zoom_left=40,
    zoom_right=10,
)

# %%
create_subplots(
    ts_dataset,
    feature=[('o10o_componente_corrente_fase_1', 'Componente corrente fase 1', 'Ampere')],
    models=origin_models,
    plotpath=f'plots/',
    n_example=10,
    zoom_left=50,
    zoom_right=18,
)
